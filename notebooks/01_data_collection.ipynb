# %% [markdown]
# # Data Collection
#
# This notebook demonstrates data collection for Overwatch match predictions.
#
# ## Overview
# - Generate synthetic match data
# - Validate data quality
# - Explore data distributions

# %%
import sys
from pathlib import Path

# Add src to path
sys.path.insert(0, str(Path().resolve().parent.parent / "src"))

from src.data.generate_synthetic import generate_synthetic_data
import pandas as pd

# Generate synthetic data
data_dir = Path().resolve().parent.parent / "data" / "raw"
data_dir.mkdir(parents=True, exist_ok=True)

df = generate_synthetic_data(n_matches=10000, output_path=data_dir / "synthetic_matches.csv")
df.head()
