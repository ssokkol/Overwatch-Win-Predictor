# %% [markdown]
# # Exploratory Data Analysis: Heroes
#
# Analyze hero distributions, pick rates, and role balances in match data.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path().resolve().parent.parent / "src"))

from src.utils.heroes import get_hero_metadata
import pandas as pd

metadata = get_hero_metadata()
print(f"Total heroes: {len(metadata.heroes)}")
print(f"Tanks: {len(metadata.get_heroes_by_role('Tank'))}")
print(f"DPS: {len(metadata.get_heroes_by_role('DPS'))}")
print(f"Support: {len(metadata.get_heroes_by_role('Support'))}")
